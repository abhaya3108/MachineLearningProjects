# %%
import random
class Cipher():
    key = random.randint(1,51)
        
    def __init__(self, text):
        self.text = text
        
    def encrypt(self, text): 
        result = " "

        # traverse text 
        for i in range(len(text)): 
            char = text[i] 
            
            # Encrypt uppercase characters 
            if (char.isupper()): 
                result += chr((ord(char) + Cipher.key - 65) % 26 + 65) 

            # Encrypt lowercase characters 
            else: 
                result += chr((ord(char) + Cipher.key - 97) % 26 + 97) 

        return result 

    def decrypt(self, text): 
        result = " " 

        # traverse text 
        for i in range(len(text)): 
            char = text[i] 
            
            # Encrypt uppercase characters 
            if (char.isupper()): 
                result += chr((ord(char) - Cipher.key - 65) % 26 + 65) 

            # Encrypt lowercase characters 
            else: 
                result += chr((ord(char) - Cipher.key - 97) % 26 + 97) 

        return result 

c = Cipher('Abhaya')
print(c.encrypt('Abhaya'))
print(c.decrypt(c.encrypt('Abhaya')))
# Out:
#  Rsyrpr
#  wAbhaya

# %%
'''This assignment is for visualization using matplotlib:
data to use:
url=
https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv'
titanic = pd.read_csv(url)
Charts to plot:
'''

import pandas as pd
import matplotlib.pyplot as plt
url=r'https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv'
titanic = pd.read_csv(url,skip_blank_lines=True)
titanic.dropna(how="all", inplace = True)
titanic['sex'].iloc[:-1]

# '''1. Create a pie chart presenting the male/female proportion'''
# count=titanic['sex'].value_counts()
# colors = ['blue', 'orange']
# f, (ax1, ax2) = plt.subplots(1, 2)
# ax1.pie(count.values.tolist(), labels=count.index.values.tolist(), colors=colors,startangle=90,
#         autopct='%.1f%%')
# ax1.set_title('Male/Female proportion')

# '''2. Create a scatterplot with the Fare paid and the Age, 
# differ the plot color by gender'''

# colors = {'male':'blue', 'female':'orange'}
# ax2.scatter(titanic.fare,titanic.age,c=titanic['sex'].iloc[:-1].apply(lambda x: 
#     colors[x]))
# ax2.set_xlabel('Fare')
# ax2.set_ylabel('Age')
# ax2.set_title('Fare paid and the Age')
# Out:
# 0       female
# 1         male
# 2       female
# 3         male
# 4       female
# 5         male
# 6       female
# 7         male
# 8       female
# 9         male
# 10        male
# 11      female
# 12      female
# 13      female
# 14        male
# 15        male
# 16        male
# 17      female
# 18      female
# 19        male
# 20        male
# 21      female
# 22        male
# 23      female
# 24      female
# 25        male
# 26        male
# 27      female
# 28      female
# 29        male
#          ...
# 1278      male
# 1279    female
# 1280      male
# 1281      male
# 1282      male
# 1283      male
# 1284      male
# 1285      male
# 1286    female
# 1287      male
# 1288      male
# 1289      male
# 1290    female
# 1291      male
# 1292      male
# 1293      male
# 1294      male
# 1295      male
# 1296      male
# 1297      male
# 1298      male
# 1299      male
# 1300    female
# 1301      male
# 1302      male
# 1303      male
# 1304    female
# ...

# %%
x = [7,2,0,3,4,2,5,0,3,4]
count = 0
pos = 0
y = []
for i in x:
    if i != 0:
        pos += 1
    else:
        pos = 0
    y.append(pos)
y
# Out:
# [1, 2, 0, 1, 2, 3, 4, 0, 1, 2]

# %%
from scipy import stats
stats.binom.pmf(6,10,0.5)
# Out:
# 0.20507812500000022

# %%
stats.binom.pmf(4,12,0.2)
stats.binom.cdf(4,12,0.2)
# Out:
# 0.92744450048

# %%
stats.poisson.pmf(2,2.3)
1 - stats.poisson.cdf(0,4.6)
# Out:
# 0.9899481642553665

# %%
stats.norm(0,1).cdf(1.9) - stats.norm(0,1).cdf(0.9)
# Out:
# 0.15534356553075768

# %%
stats.norm.ppf(0.5,loc=0,scale=1.0)
# Out:
# 0.0

# %%
1 - stats.norm(527,112).cdf(500)
# Out:
# 0.5952501217429682

# %%
stats.norm(527,112).ppf(0.95)
# Out:
# 711.2236062185649

# %%
import math
x = 1.5/math.sqrt(50)
stats.norm(25,x).cdf(25.5) - stats.norm(25,x).cdf(24.7)
# Out:
# 0.9121393337478084

# %%
stats.norm.ppf(0.000000038)
# Out:
# -5.376375993239762

# %%
stats.norm.ppf(0.995)
# Out:
# 2.5758293035489004

# %%
import statsmodels.stats.api as sms

# %%
def word_count(str):
    counts = dict()
    words = str.split()

    for word in words:
        if word in counts:
            counts[word] += 1
        else:
            counts[word] = 1

    counts_x = sorted(counts.items(), key=lambda kv: kv[1])
    #print(counts_x)
    return counts_x[-2]
 
print(word_count("Both of these issues are fixed by postponing the evaluation of annotations. Instead of compiling code which executes expressions in annotations at their definition time, the compiler stores the annotation in a string form equivalent to the AST of the expression in question. If needed, annotations can be resolved at runtime using typing.get_type_hints(). In the common case where this is not required, the annotations are cheaper to store (since short strings are interned by the interpreter) and make startup time faster."))
# Out:
# ('of', 4)

# %%
f = open('macbeth.txt')
mystr = ''
for word in f.read().split():
    mystr += word
mystr

def word_count(str):
    counts = dict()
    words = str.split()

    for word in words:
        if word in counts:
            counts[word] += 1
        else:
            counts[word] = 1

    counts_x = sorted(counts.items(), key=lambda kv: kv[1])
    #print(counts_x)
    return counts_x[-2]
 
print(word_count(mystr))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-6b7cf8962489> in <module>
#      19     return counts_x[-2]
#      20
# ---> 21 print(word_count(mystr))
#
# <ipython-input-22-6b7cf8962489> in word_count(str)
#      17     counts_x = sorted(counts.items(), key=lambda kv: kv[1])
#      18     #print(counts_x)
# ---> 19     return counts_x[-2]
#      20
#      21 print(word_count(mystr))
#
# IndexError: list index out of range

# %%
(1 - stats.t.cdf(1.46,24)) * 2
# Out:
# 0.15725736054406458

# %%
stats.t.ppf(0.95, 40)
# Out:
# 1.68385101138658

# %%
s = ((212**2/1200) + (185**2/800))**0.5
stats.norm.ppf(0.975)
# Out:
# 1.959963984540054

# %%
s = 2.5/(35**0.5)
z = (14.6- 15.4)/s
stats.norm.cdf(z) * 2
# Out:
# 0.058338518686896344

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
data = pd.read_csv('http://www-bcf.usc.edu/~gareth/ISL/Advertising.csv', index_col=0)
data.head()
data.shape
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-23-2e37d8d9a0a6> in <module>
#       2 import matplotlib.pyplot as plt
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 4 data = pd.read_csv('http://www-bcf.usc.edu/~gareth/ISL/Advertising.csv', index_col=0)
#       5 data.head()
#       6 data.shape
#
# ...

# %%
fig, axes = plt.subplots(1, 3, sharey=True)
data.plot(kind='scatter', x='TV', y='sales',ax=axes[0],figsize=(16,8))
data.plot(kind='scatter', x='radio', y='sales',ax=axes[1],figsize=(16,8))
data.plot(kind='scatter', x='newspaper', y='sales',ax=axes[2],figsize=(16,8))

# %%
data.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %%
feature_cols=['TV']
X = data[feature_cols]
y = data.sales

from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X,y)

print(lm.intercept_)
print(lm.coef_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-ae8ec66bef42> in <module>
#       1 feature_cols=['TV']
# ----> 2 X = data[feature_cols]
#       3 y = data.sales
#       4
#       5 from sklearn.linear_model import LinearRegression
#
# NameError: name 'data' is not defined

# %%
X_new = pd.DataFrame({'TV': [data.TV.min(), data.TV.max()]})
X_new.head()
# Out:
#       TV
# 0    0.7
# 1  296.4

# %%
preds = lm.predict(X_new)
preds
# Out:
# array([ 7.0658692 , 21.12245377])

# %%
data.plot(kind='scatter',x='TV',y='sales')
plt.plot(X_new,preds,c='red',linewidth=2)

# %%
import statsmodels.formula.api as smf
lm = smf.ols(formula='sales~TV + newspaper',data=data).fit()
lm.conf_int()
lm.pvalues
lm.rsquared
lm.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-1e402a2a9a1b> in <module>
#       1 import statsmodels.formula.api as smf
# ----> 2 lm = smf.ols(formula='sales~TV + newspaper',data=data).fit()
#       3 lm.conf_int()
#       4 lm.pvalues
#       5 lm.rsquared
#
# NameError: name 'data' is not defined

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
def findArmstrong(num):
    while(num):
        num1 == num
        sum = 0
        while(num1 > 0):
            rem = num1 % 10
            sum += (rem**3)
            num1 //= 10
            if sum == num1:
            print(sum, "is an armstrong number")
        num -=1
        
#findArmstrong(1000)
12+2

# %%
str1 = "20G ./padhsou 24G ./Abhaya 26G ./Shisher"
col1=[]
col2=[]
list2=str1.split(' ')
list2
[col1.append(list2[i]) if i%2==0 else col2.append(list2[i]) for i in range(len(list2))]
for i in range(len(col1)):
    for j in range(len(col2)):
        if(i==j):
            print (col1[i] + "\t" + col2[j])
# Out:
# 20G	./padhsou
# 24G	./Abhaya
# 26G	./Shisher

# %%
import scipy.stats
t = (48574-48432)/(2000/20)
t
# Out:
# 1.42

# %%
scipy.stats.t.ppf(0.95,399)
# Out:
# 1.6486815335554057

# %%
1 - scipy.stats.norm.cdf(1.42)
# Out:
# 0.07780384052654643

# %%
scipy.stats.t.ppf(0.95,40)
# Out:
# 1.68385101138658

# %%
z = (14.6-15.4)/(2.5/(35**(0.5)))
z
# Out:
# -1.8931455305918787

# %%
scipy.stats.t.ppf(0.975,34)
# Out:
# 2.032244509317718

# %%
2*(1 - scipy.stats.norm.cdf(z))
# Out:
# 1.9416614813131037

# %%
import pandas as pd
data = pd.read_html("https://www.worldometers.info/coronavirus/")
data[0]
# Out:
#               Country,Other  TotalCases NewCases  TotalDeaths  NewDeaths  \
# 0                     China       81285      +67       3287.0        6.0
# 1                     Italy       80539   +6,153       8165.0      662.0
# 2                       USA       75665   +7,454       1100.0       73.0
# 3                     Spain       56197   +6,682       4145.0      498.0
# 4                   Germany       43646   +6,323        239.0       33.0
# 5                      Iran       29406   +2,389       2234.0      157.0
# 6                    France       25233      NaN       1331.0        NaN
# 7               Switzerland       11712     +815        191.0       38.0
# 8                        UK        9849     +320        477.0       12.0
# 9                  S. Korea        9241     +104        131.0        5.0
# 10              Netherlands        7431   +1,019        434.0       78.0
# 11                  Austria        6703   +1,115         49.0       18.0
# ...

# %%
data[0].iloc[42]
# Out:
# Country,Other        India
# TotalCases             562
# NewCases               +26
# TotalDeaths             10
# NewDeaths              NaN
# TotalRecovered          40
# ActiveCases            512
# Serious,Critical       NaN
# Tot Cases/1M pop       0.4
# Tot Deaths/1M pop     0.01
# Name: 42, dtype: object

# %%
data = pd.read_csv(r"C:\Users\panda4\Documents\Data Science\notebooks\auto_insurance_sweden.csv", header=None)
data = data.rename(columns={0: "X", 1: "Y"})
data
# Out:
#       X      Y
# 0   108  392.5
# 1    19   46.2
# 2    13   15.7
# 3   124  422.2
# 4    40  119.4
# 5    57  170.9
# 6    23   56.9
# 7    14   77.5
# 8    45  214.0
# 9    10   65.3
# 10    5   20.9
# 11   48  248.1
# 12   11   23.5
# 13   23   39.6
# 14    7   48.8
# 15    2    6.6
# 16   24  134.9
# 17    6   50.9
# 18    3    4.4
# 19   23  113.0
# 20    6   14.8
# 21    9   48.7
# 22    9   52.1
# 23    3   13.2
# 24   29  103.9
# 25    7   77.5
# 26    4   11.8
# 27   20   98.1
# 28    7   27.9
# 29    4   38.1
# ..  ...    ...
# 33    5   40.3
# 34   22  161.5
# 35   11   57.2
# 36   61  217.6
# 37   12   58.1
# 38    4   12.6
# 39   16   59.6
# 40   13   89.9
# 41   60  202.4
# 42   41  181.3
# 43   37  152.8
# 44   55  162.8
# 45   41   73.4
# 46   11   21.3
# 47   27   92.6
# 48    8   76.1
# 49    3   39.9
# 50   17  142.1
# 51   13   93.0
# 52   13   31.9
# 53   15   32.1
# 54    8   55.6
# 55   29  133.3
# 56   30  194.5
# 57   24  137.9
# 58    9   87.4
# ...

# %%
data.plot.scatter(x='X', y='Y')

# %%
data.corr()
# Out:
#           X         Y
# X  1.000000  0.912878
# Y  0.912878  1.000000

# %%
col = ['X']
X = data[col]
y = data.Y

from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X, y)

print(lm.intercept_)
print(lm.coef_)
# Out:
# 19.994485759114795
# [3.41382356]

# %%
X_new = pd.DataFrame({'X':[50, 20]})
lm.predict(X_new)
# Out:
# array([190.68566376,  88.27095696])

# %%
X_new = pd.DataFrame({'X':[data.X.min(), data.X.max()]})
X_new
# Out:
#      X
# 0    0
# 1  124

# %%
preds = lm.predict(X_new)
preds
# Out:
# array([ 19.99448576, 443.30860721])

# %%
import matplotlib.pyplot as plt
data.plot(kind='scatter', x='X', y='Y')
plt.plot(X_new,preds,c='red',linewidth=2)

# %%
import statsmodels.formula.api as smf
results = smf.ols('Y ~ X', data=data).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.833
# Model:                            OLS   Adj. R-squared:                  0.831
# Method:                 Least Squares   F-statistic:                     305.0
# Date:                Wed, 18 Mar 2020   Prob (F-statistic):           2.05e-25
# Time:                        00:14:06   Log-Likelihood:                -314.04
# No. Observations:                  63   AIC:                             632.1
# Df Residuals:                      61   BIC:                             636.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     19.9945      6.368      3.140      0.003       7.261      32.728
# ...

# %%
data = pd.read_csv(r"C:\Users\panda4\Downloads\train_20D8GL3.csv")
data
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0      25150     360000    2          2         2   25     -1     -1     -1
# 1      13470     240000    2          1         2   46      2      2     -2
# 2       3092     320000    2          2         1   41      0      0      0
# 3      13973      50000    2          2         2   24     -1     -1     -2
# 4      10567      80000    1          3         1   52     -1      0      0
# 5      28050     150000    2          1         2   29     -2     -2     -2
# 6      23327     260000    2          1         1   36      0      0      0
# 7      10728      50000    2          2         1   31      0      0      0
# 8      17227     130000    2          2         2   24      0      0      0
# 9      22039      60000    2          3         2   28     -1     -1      0
# 10       196      50000    2          1         2   24      1      2      2
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
corr = data.corr()
plt.figure(figsize=(20,20))
ax = sns.heatmap(
    corr>0.9, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True,linewidths=0.5
)
ax.plot()
# Out:
# []

# %%
data.corr()
# Out:
#                                   ID  LIMIT_BAL       SEX  EDUCATION  \
# ID                          1.000000   0.029309  0.023360   0.035009
# LIMIT_BAL                   0.029309   1.000000  0.029683  -0.216762
# SEX                         0.023360   0.029683  1.000000   0.011012
# EDUCATION                   0.035009  -0.216762  0.011012   1.000000
# MARRIAGE                   -0.025129  -0.110451 -0.033930  -0.143085
# AGE                         0.017725   0.143206 -0.092907   0.172253
# PAY_0                      -0.029347  -0.272059 -0.061232   0.105815
# PAY_2                      -0.011643  -0.297323 -0.072602   0.119132
# PAY_3                      -0.019846  -0.290059 -0.064406   0.110223
# PAY_4                      -0.004922  -0.269652 -0.061242   0.103607
# PAY_5                      -0.021758  -0.253399 -0.055920   0.094702
# PAY_6                      -0.019846  -0.235601 -0.045045   0.080033
# BILL_AMT1                   0.014660   0.290539 -0.031595   0.027826
# ...
